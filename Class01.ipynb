# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/NeuralNetworksAndDeepLearning/blob/main/Class01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Artificial Neural Networks**
# Artificial Neural Networks (ANNs) are machine learning models inspired by the human brain that learn from data to recognize patterns and make predictions. They consist of interconnected layers of neurons whose connection weights are adjusted during training using algorithms such as backpropagation and gradient descent to minimize errors. ANNs are especially effective at handling complex, non-linear problems and can generalize knowledge to new data, enabling applications in areas like image recognition, healthcare, finance, and security. Despite their strong performance, challenges such as high computational cost, need for large and high-quality datasets, and limited interpretability (“black box” nature) remain important considerations.

# %%
# Importing all the necessary libraries and resources:
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Generating a simple synthetic customer dataset. Features: [monthly_usage, contract_length, support_calls]:
X = np.array([
    [50, 12, 1],
    [20, 3, 5],
    [70, 24, 0],
    [10, 1, 7],
    [90, 36, 0],
    [30, 6, 4],
    [80, 18, 1],
    [15, 2, 6]
])

# Labels: 1 = churned, 0 = stayed
y = np.array([0, 1, 0, 1, 0, 1, 0, 1])

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Normalizing the features:
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Building the ANN model:
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compiling the model:
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Training the ANN:
model.fit(X_train, y_train, epochs=40, batch_size=2, verbose=1)

# Evaluating the model:
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.2f}')

# Making a prediction for a new customer:
new_customer = np.array([[25, 4, 5]])  # low usage, short contract, many support calls
new_customer_scaled = scaler.transform(new_customer)

prediction = model.predict(new_customer_scaled)
print('Churn Probability:', float(prediction))
# Out:
# Epoch 1/40
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.5833 - loss: 0.6774
# Epoch 2/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6458 - loss: 0.6370
# Epoch 3/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7708 - loss: 0.6151
# Epoch 4/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5833 - loss: 0.6659
# Epoch 5/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4583 - loss: 0.6615
# Epoch 6/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4583 - loss: 0.6552
# Epoch 7/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6458 - loss: 0.6302
# Epoch 8/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6458 - loss: 0.6262
# Epoch 9/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7292 - loss: 0.5975
# Epoch 10/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7292 - loss: 0.6331
# Epoch 11/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7292 - loss: 0.6504
# Epoch 12/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7292 - loss: 0.6047
# Epoch 13/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7292 - loss: 0.6210
# Epoch 14/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7292 - loss: 0.5699
# Epoch 15/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9167 - loss: 0.5318
# Epoch 16/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9167 - loss: 0.5263
# Epoch 17/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7292 - loss: 0.5375
# Epoch 18/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9167 - loss: 0.4634
# Epoch 19/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7292 - loss: 0.5222
# Epoch 20/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9167 - loss: 0.5067
# Epoch 21/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7292 - loss: 0.5385
# Epoch 22/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8542 - loss: 0.5810
# Epoch 23/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.4942
# Epoch 24/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9167 - loss: 0.4900
# Epoch 25/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.4860
# Epoch 26/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9167 - loss: 0.5044
# Epoch 27/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8542 - loss: 0.5063
# Epoch 28/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7292 - loss: 0.5776
# Epoch 29/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.5287
# Epoch 30/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8542 - loss: 0.4969
# Epoch 31/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7292 - loss: 0.5379
# Epoch 32/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8542 - loss: 0.5576
# Epoch 33/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8542 - loss: 0.5528
# Epoch 34/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7292 - loss: 0.5598
# Epoch 35/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8542 - loss: 0.3925
# Epoch 36/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9167 - loss: 0.4839
# Epoch 37/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9167 - loss: 0.3822
# Epoch 38/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9167 - loss: 0.5409
# Epoch 39/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7292 - loss: 0.5515
# Epoch 40/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.4676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.2582
# Test Accuracy: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Churn Probability: 0.7887747287750244
# /tmp/ipython-input-1957853466.py:51: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('Churn Probability:', float(prediction))
